# %%
# import some common detectron2 utilities
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog
import matplotlib.pyplot as plt
import cv2
import numpy as np


# get image
im = cv2.imread("input.jpg")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-b2b690dd98f9> in <module>
#       8 import numpy as np
#       9
# ---> 10 from centermask.config import get_cfg
#      11 from centermask.checkpoint import AdetCheckpointer
#      12
#
# ModuleNotFoundError: No module named 'centermask'

# %%
# Create config
cfg = get_cfg()
#cfg.merge_from_file("../detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.merge_from_file("../detectron2/configs/centermask/centermask_V_39_eSE_FPN_ms_3x.yaml")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
#cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl"
cfg.MODEL.WEIGHTS = "/home/josmar/proyectos/centermask2/centermask2-V-39-eSE-FPN-ms-3x.pth"
# Create predictor
predictor = DefaultPredictor(cfg)

# Make prediction
outputs = predictor(im)

v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
out=v.get_image()[:, :, ::-1]
cv2.imshow("lol",out)
k = cv2.waitKey(0)
if k == 27: # wait for ESC key to exit
  cv2.destroyAllWindows()
# Out:
# Config '../detectron2/configs/centermask/centermask_V_39_eSE_FPN_ms_3x.yaml' has no VERSION. Assuming it to be compatible with latest v2.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2fd08e34a8b9> in <module>
#       2 cfg = get_cfg()
#       3 #cfg.merge_from_file("../detectron2/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
# ----> 4 cfg.merge_from_file("../detectron2/configs/centermask/centermask_V_39_eSE_FPN_ms_3x.yaml")
#       5 cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
#       6 #cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl"
#
# ~/.conda/envs/d2/lib/python3.6/site-packages/detectron2/config/config.py in merge_from_file(self, cfg_filename, allow_unsafe)
#      47
#      48         if loaded_ver == self.VERSION:
# ---> 49             self.merge_from_other_cfg(loaded_cfg)
#      50         else:
#      51             # compat.py needs to import CfgNode
#
# ~/.conda/envs/d2/lib/python3.6/site-packages/fvcore/common/config.py in merge_from_other_cfg(self, cfg_other)
#     118             BASE_KEY not in cfg_other  # pyre-ignore
#     119         ), "The reserved key '{}' can only be used in files!".format(BASE_KEY)
# --> 120         return super().merge_from_other_cfg(cfg_other)
#     121
#     122     def merge_from_list(self, cfg_list: List[object]) -> Callable[[], None]:
#
# ~/.conda/envs/d2/lib/python3.6/site-packages/yacs/config.py in merge_from_other_cfg(self, cfg_other)
#     215     def merge_from_other_cfg(self, cfg_other):
#     216         """Merge `cfg_other` into this CfgNode."""
# --> 217         _merge_a_into_b(cfg_other, self, self, [])
#     218
#     219     def merge_from_list(self, cfg_list):
#
# ~/.conda/envs/d2/lib/python3.6/site-packages/yacs/config.py in _merge_a_into_b(a, b, root, key_list)
#     462             if isinstance(v, CfgNode):
#     463                 try:
# --> 464                     _merge_a_into_b(v, b[k], root, key_list + [k])
#     465                 except BaseException:
#     466                     raise
#
# ~/.conda/envs/d2/lib/python3.6/site-packages/yacs/config.py in _merge_a_into_b(a, b, root, key_list)
#     475                 root.raise_key_rename_error(full_key)
#     476             else:
# --> 477                 raise KeyError("Non-existent config key: {}".format(full_key))
#     478
#     479
#
# KeyError: 'Non-existent config key: MODEL.VOVNET'

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 2
rows = 1
for i in range(1, columns*rows +1):
    img = np.random.randint(10, size=(h,w))
    fig.add_subplot(rows, columns, i)
    plt.imshow(img)
plt.show()

# %%
fig=plt.figure(figsize=(8, 8))
columns = 2
rows = 1
fig.add_subplot(rows, columns, 1)
plt.imshow(out)
fig.add_subplot(rows, columns, 2)
plt.imshow(cv2.cvtColor(out, cv2.COLOR_BGR2GRAY))
plt.show()
